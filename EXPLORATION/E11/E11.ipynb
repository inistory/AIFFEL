# %% [markdown]
# ## 1. Set-up

# %%
import re
import os
import pandas as pd
import numpy as np
import tensorflow as tf
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split

# %% [markdown]
# ## 2. 데이터 가져오기

# %%
# 데이터 로드할 때 빠르게 로드할 수 있도록하는 설정 변수
AUTOTUNE = tf.data.experimental.AUTOTUNE

# 데이터 ROOT 경로 변수
ROOT_PATH = os.path.join(os.getenv('HOME'), 'aiffel')

# BATCH_SIZE 변수
BATCH_SIZE = 16

# X-RAY 이미지 사이즈 변수
IMAGE_SIZE = [180, 180]

# EPOCH 크기 변수
EPOCHS = 40

# %%
train_filenames = tf.io.gfile.glob(str(ROOT_PATH + '/chest_xray/data/train/*/*'))
test_filenames = tf.io.gfile.glob(str(ROOT_PATH + '/chest_xray/data/test/*/*'))
val_filenames = tf.io.gfile.glob(str(ROOT_PATH + '/chest_xray/data/val/*/*'))


print(len(train_filenames))
print(len(test_filenames))
print(len(val_filenames))
# Out:
# 5216
# 624
# 16

# %%
filenames = tf.io.gfile.glob(str(ROOT_PATH + '/chest_xray/data/train/*/*'))
filenames.extend(tf.io.gfile.glob(str(ROOT_PATH + '/chest_xray/data/val/*/*')))

train_filenames, val_filenames = train_test_split(filenames, test_size=0.2)

print(len(train_filenames))
print(len(val_filenames))
# Out:
# 4185
# 1047

# %%
COUNT_NORMAL = len([filename for filename in train_filenames if "NORMAL" in filename])
print("Normal images count in training set: " + str(COUNT_NORMAL))

COUNT_PNEUMONIA = len([filename for filename in train_filenames if "PNEUMONIA" in filename])
print("Pneumonia images count in training set: " + str(COUNT_PNEUMONIA))
# Out:
# Normal images count in training set: 1077
# Pneumonia images count in training set: 3108

# %%
train_list_ds = tf.data.Dataset.from_tensor_slices(train_filenames)
val_list_ds = tf.data.Dataset.from_tensor_slices(val_filenames)

# %%
TRAIN_IMG_COUNT = tf.data.experimental.cardinality(train_list_ds).numpy()
print("Training images count: " + str(TRAIN_IMG_COUNT))

VAL_IMG_COUNT = tf.data.experimental.cardinality(val_list_ds).numpy()
print("Validating images count: " + str(VAL_IMG_COUNT))
# Out:
# Training images count: 4185
# Validating images count: 1047

# %%
CLASS_NAMES = np.array([str(tf.strings.split(item, os.path.sep)[-1].numpy())[2:-1]
                        for item in tf.io.gfile.glob(str(ROOT_PATH + "/chest_xray/train/*"))])
print(CLASS_NAMES)
# Out:
# []

# %%
def get_label(file_path):
    parts = tf.strings.split(file_path, os.path.sep)
    return parts[-2] == "PNEUMONIA"   # 폐렴이면 양성(True), 노말이면 음성(False)를 리턴하게 합니다.

# %%
def decode_img(img):
  # 이미지를 uint8 tensor로 바꾼다.
  img = tf.image.decode_jpeg(img, channels=3)
  # img를 범위 [0,1]의 float32 데이터 타입으로 바꾼다.
  img = tf.image.convert_image_dtype(img, tf.float32)
  # img의 이미지 사이즈를 IMAGE_SIZE에서 지정한 사이즈로 수정한다.
  return tf.image.resize(img, IMAGE_SIZE)

def process_path(file_path):
    label = get_label(file_path)
    img = tf.io.read_file(file_path)
    img = decode_img(img)
    return img, label

# %%
train_ds = train_list_ds.map(process_path, num_parallel_calls=AUTOTUNE)
val_ds = val_list_ds.map(process_path, num_parallel_calls=AUTOTUNE)

# %%
for image, label in train_ds.take(1):
    print("Image shape: ", image.numpy().shape)
    print("Label: ", label.numpy())
# Out:
# Image shape:  (180, 180, 3)
# Label:  True

# %%
test_list_ds = tf.data.Dataset.list_files(str(ROOT_PATH + '/chest_xray/data/test/*/*'))
TEST_IMAGE_COUNT = tf.data.experimental.cardinality(test_list_ds).numpy()
test_ds = test_list_ds.map(process_path, num_parallel_calls=AUTOTUNE)
test_ds = test_ds.batch(BATCH_SIZE)

print(TEST_IMAGE_COUNT)
# Out:
# 624

# %%
def prepare_for_training(ds, shuffle_buffer_size=1000):

    ds = ds.shuffle(buffer_size=shuffle_buffer_size)

    ds = ds.repeat()

    ds = ds.batch(BATCH_SIZE)

    ds = ds.prefetch(buffer_size=AUTOTUNE)

    return ds

train_ds_basic = prepare_for_training(train_ds)
val_ds_basic = prepare_for_training(val_ds)

# %%
def augment(image,label):
    image = tf.image.random_flip_left_right(image)  # 랜덤하게 좌우를 반전합니다.
    
    return image,label

def prepare_for_training_aug(ds, shuffle_buffer_size=1000):
    # augment 적용 부분이 배치처리 함수에 추가되었습니다.
    ds = ds.map(
            augment,       # augment 함수 적용
            num_parallel_calls=2
        )

    ds = ds.shuffle(buffer_size=shuffle_buffer_size)

    ds = ds.repeat()

    ds = ds.batch(BATCH_SIZE)

    ds = ds.prefetch(buffer_size=AUTOTUNE)

    return ds

train_aug_ds = prepare_for_training_aug(train_ds)
val_aug_ds = prepare_for_training_aug(val_ds)

# %% [markdown]
# ## 3. 데이터 시각화

# %%
image_batch, label_batch = next(iter(train_ds_basic))

def show_batch(image_batch, label_batch):
    plt.figure(figsize=(10,10))
    print(image_batch.shape)
    print(label_batch.shape)
    for n in range(16):
        ax = plt.subplot(5,5,n+1)
        plt.imshow(image_batch[n])
        if label_batch[n]:
            plt.title("PNEUMONIA")
        else:
            plt.title("NORMAL")
        plt.axis("off")

show_batch(image_batch.numpy(), label_batch.numpy())
# Out:
# (16, 180, 180, 3)
# (16,)

# %%
image_aug_batch, label_aug_batch = next(iter(train_aug_ds))

def show_batch(image_batch, label_batch):
    plt.figure(figsize=(10,10))
    print(image_batch.shape)
    print(label_batch.shape)
    for n in range(16):
        ax = plt.subplot(5,5,n+1)
        plt.imshow(image_batch[n])
        if label_batch[n]:
            plt.title("PNEUMONIA")
        else:
            plt.title("NORMAL")
        plt.axis("off")

show_batch(image_aug_batch.numpy(), label_aug_batch.numpy())
# Out:
# (16, 180, 180, 3)
# (16,)

# %% [markdown]
# ## 4. CNN 모델링

# %%
def conv_block(layer, filters):
    x = tf.keras.layers.SeparableConv2D(filters, 3, activation='relu', padding='same')(layer)
    x = tf.keras.layers.SeparableConv2D(filters, 3, activation='relu', padding='same')(x)
    x = tf.keras.layers.BatchNormalization()(x)
    x = tf.keras.layers.MaxPool2D()(x)

    return x

# %%
def dense_block(layer, units, dropout_rate=0.5, dropout=True):
    x = tf.keras.layers.Dense(units, activation='relu')(layer)
    x = tf.keras.layers.BatchNormalization()(x)
    if dropout:
        x = tf.keras.layers.Dropout(dropout_rate)(x)
    
    return x

# %%
def build_model(dropout=True):
    input_layer = tf.keras.Input(shape=(IMAGE_SIZE[0], IMAGE_SIZE[1], 3))
    
    x = tf.keras.layers.Conv2D(16, 3, activation='relu', padding='same')(input_layer)
    x = tf.keras.layers.Conv2D(16, 3, activation='relu', padding='same')(x)
    x = tf.keras.layers.MaxPool2D()(x)
    
    x = conv_block(x, 32)
    x = conv_block(x, 64)
    
    x = conv_block(x, 128)
    if dropout:
        x = tf.keras.layers.Dropout(0.2)(x)
    
    x = conv_block(x, 256)
    if dropout:
        x = tf.keras.layers.Dropout(0.2)(x)
    
    x = tf.keras.layers.Flatten()(x)
    x = dense_block(x, 512, 0.7)
    x = dense_block(x, 128, 0.5)
    x = dense_block(x, 64, 0.3)
    
    output = tf.keras.layers.Dense(1, activation='sigmoid')(x)
    
    model = tf.keras.Model(inputs=input_layer, outputs=output)
    
    return model

# %% [markdown]
# ## 5. 데이터 imbalance 처리

# %%
weight_for_0 = (1 / COUNT_NORMAL)*(TRAIN_IMG_COUNT)/2.0 
weight_for_1 = (1 / COUNT_PNEUMONIA)*(TRAIN_IMG_COUNT)/2.0

class_weight = {0: weight_for_0, 1: weight_for_1}

print('Weight for class 0: {:.2f}'.format(weight_for_0))
print('Weight for class 1: {:.2f}'.format(weight_for_1))
# Out:
# Weight for class 0: 1.94
# Weight for class 1: 0.67

# %% [markdown]
# ## 6. 모델 훈련

# %%
with tf.device('/GPU:0'):
    model = build_model()

    METRICS = [
        'accuracy',
        tf.keras.metrics.Precision(name='precision'),
        tf.keras.metrics.Recall(name='recall')
    ]
    
    model.compile(
        optimizer=tf.keras.optimizers.Adam(learning_rate=0.001, beta_1=0.9, beta_2=0.999),
        loss='binary_crossentropy',
        metrics=METRICS
    )

# %%
with tf.device('/GPU:0'):
    history = model.fit(
        train_ds_basic,
        steps_per_epoch=TRAIN_IMG_COUNT // BATCH_SIZE,
        epochs=EPOCHS,
        validation_data=val_ds_basic,
        validation_steps=VAL_IMG_COUNT // BATCH_SIZE,
        class_weight=class_weight,
    )
# Out:
# Epoch 1/40
# 261/261 [==============================] - 92s 240ms/step - loss: 0.5802 - accuracy: 0.6993 - precision: 0.8979 - recall: 0.6682 - val_loss: 0.6499 - val_accuracy: 0.7413 - val_precision: 0.7413 - val_recall: 1.0000
# Epoch 2/40
# 261/261 [==============================] - 60s 231ms/step - loss: 0.2182 - accuracy: 0.9168 - precision: 0.9790 - recall: 0.9064 - val_loss: 0.9948 - val_accuracy: 0.7404 - val_precision: 0.7404 - val_recall: 1.0000
# Epoch 3/40
# 261/261 [==============================] - 61s 235ms/step - loss: 0.1981 - accuracy: 0.9228 - precision: 0.9742 - recall: 0.9196 - val_loss: 0.1462 - val_accuracy: 0.9404 - val_precision: 0.9286 - val_recall: 0.9961
# Epoch 4/40
# 261/261 [==============================] - 62s 238ms/step - loss: 0.1631 - accuracy: 0.9352 - precision: 0.9799 - recall: 0.9316 - val_loss: 0.0903 - val_accuracy: 0.9692 - val_precision: 0.9804 - val_recall: 0.9779
# Epoch 5/40
# 261/261 [==============================] - 63s 240ms/step - loss: 0.1257 - accuracy: 0.9558 - precision: 0.9892 - recall: 0.9503 - val_loss: 0.3865 - val_accuracy: 0.8683 - val_precision: 0.9984 - val_recall: 0.8231
# Epoch 6/40
# 261/261 [==============================] - 67s 257ms/step - loss: 0.1589 - accuracy: 0.9459 - precision: 0.9804 - recall: 0.9457 - val_loss: 0.1644 - val_accuracy: 0.9394 - val_precision: 1.0000 - val_recall: 0.9182
# Epoch 7/40
# 261/261 [==============================] - 59s 226ms/step - loss: 0.1334 - accuracy: 0.9513 - precision: 0.9829 - recall: 0.9501 - val_loss: 0.1302 - val_accuracy: 0.9490 - val_precision: 0.9736 - val_recall: 0.9573
# Epoch 8/40
# 261/261 [==============================] - 58s 224ms/step - loss: 0.1476 - accuracy: 0.9428 - precision: 0.9837 - recall: 0.9390 - val_loss: 0.5932 - val_accuracy: 0.7750 - val_precision: 1.0000 - val_recall: 0.6965
# Epoch 9/40
# 261/261 [==============================] - 59s 226ms/step - loss: 0.1222 - accuracy: 0.9496 - precision: 0.9841 - recall: 0.9463 - val_loss: 0.1558 - val_accuracy: 0.9433 - val_precision: 0.9986 - val_recall: 0.9246
# Epoch 10/40
# 261/261 [==============================] - 59s 225ms/step - loss: 0.1090 - accuracy: 0.9616 - precision: 0.9887 - recall: 0.9595 - val_loss: 0.1089 - val_accuracy: 0.9558 - val_precision: 0.9986 - val_recall: 0.9416
# Epoch 11/40
# 261/261 [==============================] - 60s 232ms/step - loss: 0.1306 - accuracy: 0.9532 - precision: 0.9898 - recall: 0.9466 - val_loss: 0.1388 - val_accuracy: 0.9452 - val_precision: 0.9343 - val_recall: 0.9961
# Epoch 12/40
# 261/261 [==============================] - 59s 227ms/step - loss: 0.0985 - accuracy: 0.9620 - precision: 0.9889 - recall: 0.9588 - val_loss: 0.0879 - val_accuracy: 0.9615 - val_precision: 0.9959 - val_recall: 0.9519
# Epoch 13/40
# 261/261 [==============================] - 59s 226ms/step - loss: 0.1143 - accuracy: 0.9513 - precision: 0.9871 - recall: 0.9461 - val_loss: 0.2253 - val_accuracy: 0.9202 - val_precision: 1.0000 - val_recall: 0.8919
# Epoch 14/40
# 261/261 [==============================] - 61s 236ms/step - loss: 0.1013 - accuracy: 0.9672 - precision: 0.9878 - recall: 0.9676 - val_loss: 0.1099 - val_accuracy: 0.9596 - val_precision: 0.9973 - val_recall: 0.9479
# Epoch 15/40
# 261/261 [==============================] - 59s 227ms/step - loss: 0.1136 - accuracy: 0.9608 - precision: 0.9910 - recall: 0.9559 - val_loss: 0.5108 - val_accuracy: 0.8337 - val_precision: 0.9967 - val_recall: 0.7785
# Epoch 16/40
# 261/261 [==============================] - 58s 224ms/step - loss: 0.1444 - accuracy: 0.9407 - precision: 0.9856 - recall: 0.9346 - val_loss: 0.2018 - val_accuracy: 0.9240 - val_precision: 0.9079 - val_recall: 0.9987
# Epoch 17/40
# 261/261 [==============================] - 59s 228ms/step - loss: 0.0752 - accuracy: 0.9731 - precision: 0.9928 - recall: 0.9704 - val_loss: 0.0708 - val_accuracy: 0.9750 - val_precision: 0.9960 - val_recall: 0.9701
# Epoch 18/40
# 261/261 [==============================] - 59s 227ms/step - loss: 0.0830 - accuracy: 0.9753 - precision: 0.9948 - recall: 0.9716 - val_loss: 0.0717 - val_accuracy: 0.9750 - val_precision: 0.9844 - val_recall: 0.9818
# Epoch 19/40
# 261/261 [==============================] - 59s 227ms/step - loss: 0.0753 - accuracy: 0.9701 - precision: 0.9912 - recall: 0.9676 - val_loss: 0.0821 - val_accuracy: 0.9712 - val_precision: 0.9793 - val_recall: 0.9818
# Epoch 20/40
# 261/261 [==============================] - 61s 236ms/step - loss: 0.0654 - accuracy: 0.9797 - precision: 0.9957 - recall: 0.9771 - val_loss: 0.2437 - val_accuracy: 0.8875 - val_precision: 1.0000 - val_recall: 0.8481
# Epoch 21/40
# 261/261 [==============================] - 59s 226ms/step - loss: 0.0888 - accuracy: 0.9633 - precision: 0.9910 - recall: 0.9593 - val_loss: 0.2865 - val_accuracy: 0.9096 - val_precision: 0.8921 - val_recall: 0.9987
# Epoch 22/40
# 261/261 [==============================] - 59s 225ms/step - loss: 0.0613 - accuracy: 0.9808 - precision: 0.9945 - recall: 0.9795 - val_loss: 1.2447 - val_accuracy: 0.9029 - val_precision: 0.9024 - val_recall: 0.9740
# Epoch 23/40
# 261/261 [==============================] - 59s 226ms/step - loss: 0.1113 - accuracy: 0.9633 - precision: 0.9877 - recall: 0.9630 - val_loss: 0.0619 - val_accuracy: 0.9750 - val_precision: 0.9869 - val_recall: 0.9792
# Epoch 24/40
# 261/261 [==============================] - 59s 226ms/step - loss: 0.0632 - accuracy: 0.9804 - precision: 0.9945 - recall: 0.9789 - val_loss: 0.0815 - val_accuracy: 0.9625 - val_precision: 0.9986 - val_recall: 0.9506
# Epoch 25/40
# 261/261 [==============================] - 60s 231ms/step - loss: 0.1025 - accuracy: 0.9644 - precision: 0.9913 - recall: 0.9600 - val_loss: 0.1304 - val_accuracy: 0.9423 - val_precision: 0.9797 - val_recall: 0.9416
# Epoch 26/40
# 261/261 [==============================] - 59s 226ms/step - loss: 0.0941 - accuracy: 0.9681 - precision: 0.9915 - recall: 0.9648 - val_loss: 0.0927 - val_accuracy: 0.9606 - val_precision: 0.9986 - val_recall: 0.9481
# Epoch 27/40
# 261/261 [==============================] - 59s 226ms/step - loss: 0.0694 - accuracy: 0.9721 - precision: 0.9934 - recall: 0.9687 - val_loss: 0.1959 - val_accuracy: 0.9202 - val_precision: 0.9971 - val_recall: 0.8951
# Epoch 28/40
# 261/261 [==============================] - 59s 226ms/step - loss: 0.0689 - accuracy: 0.9716 - precision: 0.9949 - recall: 0.9666 - val_loss: 0.0683 - val_accuracy: 0.9769 - val_precision: 0.9882 - val_recall: 0.9805
# Epoch 29/40
# 261/261 [==============================] - 59s 226ms/step - loss: 0.0493 - accuracy: 0.9834 - precision: 0.9983 - recall: 0.9795 - val_loss: 0.0540 - val_accuracy: 0.9788 - val_precision: 0.9857 - val_recall: 0.9857
# Epoch 30/40
# 261/261 [==============================] - 59s 227ms/step - loss: 0.0583 - accuracy: 0.9784 - precision: 0.9959 - recall: 0.9749 - val_loss: 0.0550 - val_accuracy: 0.9817 - val_precision: 0.9934 - val_recall: 0.9819
# Epoch 31/40
# 261/261 [==============================] - 59s 225ms/step - loss: 0.0748 - accuracy: 0.9719 - precision: 0.9952 - recall: 0.9668 - val_loss: 0.0603 - val_accuracy: 0.9712 - val_precision: 0.9894 - val_recall: 0.9714
# Epoch 32/40
# 261/261 [==============================] - 58s 225ms/step - loss: 0.0588 - accuracy: 0.9790 - precision: 0.9937 - recall: 0.9777 - val_loss: 0.0727 - val_accuracy: 0.9712 - val_precision: 0.9881 - val_recall: 0.9727
# Epoch 33/40
# 261/261 [==============================] - 58s 225ms/step - loss: 0.0574 - accuracy: 0.9799 - precision: 0.9948 - recall: 0.9775 - val_loss: 0.0748 - val_accuracy: 0.9731 - val_precision: 0.9947 - val_recall: 0.9688
# Epoch 34/40
# 261/261 [==============================] - 58s 224ms/step - loss: 0.0619 - accuracy: 0.9823 - precision: 0.9944 - recall: 0.9816 - val_loss: 0.0895 - val_accuracy: 0.9683 - val_precision: 0.9960 - val_recall: 0.9610
# Epoch 35/40
# 261/261 [==============================] - 59s 225ms/step - loss: 0.0375 - accuracy: 0.9866 - precision: 0.9978 - recall: 0.9841 - val_loss: 0.0685 - val_accuracy: 0.9779 - val_precision: 0.9908 - val_recall: 0.9792
# Epoch 36/40
# 261/261 [==============================] - 59s 226ms/step - loss: 0.0354 - accuracy: 0.9897 - precision: 0.9987 - recall: 0.9875 - val_loss: 0.0864 - val_accuracy: 0.9654 - val_precision: 1.0000 - val_recall: 0.9532
# Epoch 37/40
# 261/261 [==============================] - 59s 227ms/step - loss: 0.0420 - accuracy: 0.9843 - precision: 0.9965 - recall: 0.9821 - val_loss: 0.0790 - val_accuracy: 0.9779 - val_precision: 0.9819 - val_recall: 0.9883
# Epoch 38/40
# 261/261 [==============================] - 59s 226ms/step - loss: 0.0305 - accuracy: 0.9918 - precision: 0.9978 - recall: 0.9911 - val_loss: 0.0546 - val_accuracy: 0.9827 - val_precision: 0.9921 - val_recall: 0.9844
# Epoch 39/40
# 261/261 [==============================] - 59s 227ms/step - loss: 0.0337 - accuracy: 0.9892 - precision: 0.9968 - recall: 0.9887 - val_loss: 0.0529 - val_accuracy: 0.9846 - val_precision: 0.9922 - val_recall: 0.9870
# Epoch 40/40
# 261/261 [==============================] - 59s 225ms/step - loss: 0.0362 - accuracy: 0.9863 - precision: 0.9975 - recall: 0.9839 - val_loss: 0.0849 - val_accuracy: 0.9740 - val_precision: 0.9934 - val_recall: 0.9715

# %%
loss, acc, prec, rec = model.evaluate(test_ds)
# Out:
# 39/39 [==============================] - 6s 151ms/step - loss: 1.3646 - accuracy: 0.7901 - precision: 0.7515 - recall: 0.9923

# %% [markdown]
# ## 7. 결과 확인과 시각화

# %%
fig, ax = plt.subplots(1, 4, figsize=(20, 3))
ax = ax.ravel()

for i, met in enumerate(['precision', 'recall', 'accuracy', 'loss']):
    ax[i].plot(history.history[met])
    ax[i].plot(history.history['val_' + met])
    ax[i].set_title('Model {}'.format(met))
    ax[i].set_xlabel('epochs')
    ax[i].set_ylabel(met)
    ax[i].legend(['basic_train', 'basic_val', 'aug_train', 'aug_val'])

# %%
loss, accuracy, precision, recall = model.evaluate(test_ds)
print(f'Loss: {loss},\nAccuracy: {accuracy},\nPrecision: {precision},\nRecall: {recall}')
# Out:
# 39/39 [==============================] - 6s 150ms/step - loss: 1.3646 - accuracy: 0.7901 - precision: 0.7515 - recall: 0.9923
# Loss: 1.3646215200424194,
# Accuracy: 0.7900640964508057,
# Precision: 0.7514563202857971,
# Recall: 0.9923076629638672
