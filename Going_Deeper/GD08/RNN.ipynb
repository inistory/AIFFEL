# %% [markdown]
# ![image.png](data:image/png;base64,...)
# ![image.png](data:image/png;base64,...)
# ![image.png](data:image/png;base64,...)
# - x_2 = [0.1, 0.8]

# %%
import numpy as np

Whh = np.array([[1,0],[0.4,-2]])
Wxh = np.array([[0.2,-0.5],[0.8,0.1]])
Why = np.array([[0.5,-0.2],[0.3,0.5]])

xt = np.array([[1,0],[0.4,-2]])
h0 = np.array([0,0])
ht = np.dot([Whh,Wxh],[[h0],[xt]])
print(ht)
np.exp() / np.sum(np.exp())
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-6-f99829a3b5a3> in <module>()
#       7 xt = np.array([[1,0],[0.4,-2]])
#       8 h0 = np.array([0,0])
# ----> 9 ht = np.dot([Whh,Wxh],[[h0],[xt]])
#      10 print(ht)
#
# <__array_function__ internals> in dot(*args, **kwargs)
#
# ValueError: could not broadcast input array from shape (2,2) into shape (2)

# %%
import numpy as np

W_hh = np.array([[1, 0], [0.4, -2]])
W_xh = np.array([[0.2, -0.5], [0.8, 0.1]])
W_hy = np.array([[0.5, -0.2], [0.3, 0.5]])

def ReLU(x):
    return np.maximum(x, 0)

def Softmax(x:np.array):
    exp_x = np.exp(x)
    return exp_x / exp_x.sum()

def Sigmoid(x):
    return 1/1+np.exp(-x)

x1 = [0.5, 0.2]
h0 = [0, 0]
u1 = W_hh.dot(h0) + W_xh.dot(x1)
h1 = ReLU(u1)
y1 = Softmax(W_xh.dot(h1))
print(u1)
print(h1)
print(y1)

x2 = y1
u2 = W_hh.dot(h1) + W_xh.dot(x2)
h2 = ReLU(u2)
y2 = Softmax(W_xh.dot(h2))
print(u2)
print(h2)
print(y2)
# Out:
# array([[ 1. ,  0. ],
#        [ 0.4, -2. ]])
